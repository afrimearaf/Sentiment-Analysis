# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re,nltk

# %%
data = pd.read_excel('/content/drive/MyDrive/Movie Sentiment/New/Data/NM_comment.xlsx')
data.head()
# Out:
#    Unnamed: 0     Movie Name Label                   Main Comment  \
# 0         0.0  Nishpap Munna   pos   ,"😎😎😎😎😎😎😎😋😋😋😋😋😋😋 nice movie"
# 1         1.0  Nishpap Munna   ntr                 (  নিশী মনি )"
# 2         2.0  Nishpap Munna   pos              💜,"I loved movie"
# 3         3.0  Nishpap Munna   neg             2022,","খুব ফালতু"
# 4         4.0  Nishpap Munna   neg             24," ছামার সিনেমা"
#
#                              Comment
# 0   , "😎😎😎😎😎😎😎😋😋😋😋😋😋😋 সুন্দর সিনেমা"
# 1                     (  নিশী মনি )"
# 2          💜, "আমি সিনেমা পছন্দ করি"
# 3                 2022,","খুব ফালতু"
# 4                 24, "ছামার সিনেমা"

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Movie Name', 'Label', 'Main Comment', 'Comment'], dtype='object')

# %%
data.groupby('Label').size().reset_index(name='counts')
# Out:
#   Label  counts
# 0   neg    1293
# 1   ntr     517
# 2   pos    2196

# %%
def process_comments(Comment): 
    Comment = re.sub('[^\u0980-\u09FF]',' ',Comment) #removing unnecessary punctuation
    Comment = re.sub('[?.`*^()!°¢܌Ͱ̰ߒנ~×Ҡߘ:ҰߑÍ|।;!,&%\'@#$><A-Za-z0+-9=./''""_০-৯]', '', Comment)
    Comment = re.sub(r'(\W)(?=\1)', '', Comment)
    Comment = re.sub(r'https?:\/\/.*[\r\n]*', '', Comment, flags=re.MULTILINE)
    Comment = re.sub(r'\<a href', ' ', Comment)
    Comment = re.sub(r'&amp;', '', Comment) 
    Comment = re.sub(r'<br />', ' ', Comment)
    Comment = re.sub(r'\'', ' ', Comment)
    Comment = re.sub(r'ߑͰߑ̰ߒנ', '', Comment)
    Comment = re.sub(r'ߎɰߎɰߎɍ', '', Comment)
    return Comment

# %%
# Apply the function into the dataframe
data['Cleaned'] = data['Comment'].apply(process_comments)  
data
# Out:
#       Unnamed: 0     Movie Name Label  \
# 0            0.0  Nishpap Munna   pos
# 1            1.0  Nishpap Munna   ntr
# 2            2.0  Nishpap Munna   pos
# 3            3.0  Nishpap Munna   neg
# 4            4.0  Nishpap Munna   neg
# ...          ...            ...   ...
# 4001      4001.0  Nishpap Munna   ntr
# 4002      4002.0  Nishpap Munna   ntr
# 4003      4003.0  Nishpap Munna   ntr
# 4004      4004.0  Nishpap Munna   ntr
# 4005      4005.0  Nishpap Munna   ntr
#
#                                            Main Comment  \
# 0                          ,"😎😎😎😎😎😎😎😋😋😋😋😋😋😋 nice movie"
# 1                                        (  নিশী মনি )"
# 2                                     💜,"I loved movie"
# 3                                    2022,","খুব ফালতু"
# 4                                    24," ছামার সিনেমা"
# ...                                                 ...
# 4001                                হযরত মোহাম্মদ (সাঃ)
# 4002                                                হাই
# 4003                                    হৃদয়ের বার্তা
# 4004  হে আমাদের রব, নিশ্চয় আপনি জানেন, যা আমরা গোপন ...
# 4005      ᗫᴊ ʀօɮɨ,"শাকিব খানের মতো হিট সিনেমা দেখতে চাই
#
#                                                 Comment  \
# 0                      , "😎😎😎😎😎😎😎😋😋😋😋😋😋😋 সুন্দর সিনেমা"
# 1                                        (  নিশী মনি )"
# 2                             💜, "আমি সিনেমা পছন্দ করি"
# 3                                    2022,","খুব ফালতু"
# 4                                    24, "ছামার সিনেমা"
# ...                                                 ...
# 4001                                হযরত মোহাম্মদ (সাঃ)
# 4002                                                হাই
# 4003                                    হৃদয়ের বার্তা
# 4004  হে আমাদের রব, নিশ্চয় আপনি জানেন, যা আমরা গোপন ...
# 4005      ᗫᴊ ʀօɮɨ,"শাকিব খানের মতো হিট সিনেমা দেখতে চাই
#
#                                                 Cleaned
# 0                                        সুন্দর সিনেমা
# 1                                             নিশী মনি
# 2                                 আমি সিনেমা পছন্দ করি
# 3                                            খুব ফালতু
# 4                                         ছামার সিনেমা
# ...                                                 ...
# 4001                                 হযরত মোহাম্মদ সাঃ
# 4002                                                হাই
# 4003                                    হৃদয়ের বার্তা
# 4004  হে আমাদের রব নিশ্চয় আপনি জানেন যা আমরা গোপন কর...
# 4005               শাকিব খানের মতো হিট সিনেমা দেখতে চাই
#
# [4006 rows x 6 columns]

# %%
stopwords_list ='/content/drive/MyDrive/Movie Sentiment/New/Data/stopwords-bn.txt'

# %%
def stopword_removal(Comment,stopwords= stopwords_list):
    stp,num_of_stopwords =stopwords_info(stopwords)
    result = Comment.split()
    Comments = [word.strip() for word in result if word not in stp ]
    Comments =" ".join(Comments)
    return Comments

# %%
def stopwords_info(filename):
    stp = open(filename,'r',encoding='utf-8').read().split()
    num_of_stopwords = len(stp)
    return stp,num_of_stopwords

# %%
data['Cleaned'] = data['Cleaned'].apply(stopword_removal)  
data
# Out:
#       Unnamed: 0     Movie Name Label  \
# 0            0.0  Nishpap Munna   pos
# 1            1.0  Nishpap Munna   ntr
# 2            2.0  Nishpap Munna   pos
# 3            3.0  Nishpap Munna   neg
# 4            4.0  Nishpap Munna   neg
# ...          ...            ...   ...
# 4001      4001.0  Nishpap Munna   ntr
# 4002      4002.0  Nishpap Munna   ntr
# 4003      4003.0  Nishpap Munna   ntr
# 4004      4004.0  Nishpap Munna   ntr
# 4005      4005.0  Nishpap Munna   ntr
#
#                                            Main Comment  \
# 0                          ,"😎😎😎😎😎😎😎😋😋😋😋😋😋😋 nice movie"
# 1                                        (  নিশী মনি )"
# 2                                     💜,"I loved movie"
# 3                                    2022,","খুব ফালতু"
# 4                                    24," ছামার সিনেমা"
# ...                                                 ...
# 4001                                হযরত মোহাম্মদ (সাঃ)
# 4002                                                হাই
# 4003                                    হৃদয়ের বার্তা
# 4004  হে আমাদের রব, নিশ্চয় আপনি জানেন, যা আমরা গোপন ...
# 4005      ᗫᴊ ʀօɮɨ,"শাকিব খানের মতো হিট সিনেমা দেখতে চাই
#
#                                                 Comment  \
# 0                      , "😎😎😎😎😎😎😎😋😋😋😋😋😋😋 সুন্দর সিনেমা"
# 1                                        (  নিশী মনি )"
# 2                             💜, "আমি সিনেমা পছন্দ করি"
# 3                                    2022,","খুব ফালতু"
# 4                                    24, "ছামার সিনেমা"
# ...                                                 ...
# 4001                                হযরত মোহাম্মদ (সাঃ)
# 4002                                                হাই
# 4003                                    হৃদয়ের বার্তা
# 4004  হে আমাদের রব, নিশ্চয় আপনি জানেন, যা আমরা গোপন ...
# 4005      ᗫᴊ ʀօɮɨ,"শাকিব খানের মতো হিট সিনেমা দেখতে চাই
#
#                                                 Cleaned
# 0                                         সুন্দর সিনেমা
# 1                                              নিশী মনি
# 2                                          সিনেমা পছন্দ
# 3                                                 ফালতু
# 4                                          ছামার সিনেমা
# ...                                                 ...
# 4001                                  হযরত মোহাম্মদ সাঃ
# 4002                                                হাই
# 4003                                     হৃদয়ের বার্তা
# 4004  হে রব নিশ্চয় জানেন গোপন প্রকাশ আল্লাহর নিকট গো...
# 4005                         শাকিব খানের হিট সিনেমা চাই
#
# [4006 rows x 6 columns]

# %%
data.to_excel('NM_comment_clean.xlsx')
